# %%
import tensorflow
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('data\\tweets_all.csv')

#Split into three df's based on topic
df_politics = df.loc[df['topic'].isin(["Sinn Fein", "Qanon", "Varadkar"])]
df_TV = df.loc[df['topic'].isin(["Eastenders", "Tommy Tiernan", "Eoghan McDermott"])]
df_others = df.loc[df['topic'].isin(["Pancakes", "Burren", "Daniel Kinahan", "Shamrock Rovers"])]

#Get dummy values for my sentiment scoring
y = pd.get_dummies(df['my_sentiment_for_vader']).values

# %%
#Taken from https://medium.datadriveninvestor.com/deep-learning-lstm-for-sentiment-analysis-in-tensorflow-with-keras-api-92e62cde7626
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tweet = df.clean_text.values
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(tweet)
vocab_size = len(tokenizer.word_index) + 1
encoded_docs = tokenizer.texts_to_sequences(tweet)
padded_sequence = pad_sequences(encoded_docs, maxlen=200)




#Again taken from medium website
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.layers import Embedding

embedding_vector_length = 32
model = Sequential() 
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200) )
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax')) 
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])  
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 32)           92128
#
#  spatial_dropout1d (SpatialD  (None, 200, 32)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 50)                16600
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 3)                 153
#
# =================================================================
# Total params: 108,881
# Trainable params: 108,881
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(padded_sequence, y, validation_split=0.2, epochs=10, verbose=1, batch_size=32)

hist = pd.DataFrame(history.history)

hist
# Out:
# Epoch 1/10
# 11/11 [==============================] - 6s 235ms/step - loss: 0.6866 - accuracy: 0.4231 - val_loss: 0.6746 - val_accuracy: 0.4353
# Epoch 2/10
# 11/11 [==============================] - 2s 197ms/step - loss: 0.6519 - accuracy: 0.4615 - val_loss: 0.6357 - val_accuracy: 0.4353
# Epoch 3/10
# 11/11 [==============================] - 2s 197ms/step - loss: 0.6206 - accuracy: 0.4556 - val_loss: 0.6147 - val_accuracy: 0.4353
# Epoch 4/10
# 11/11 [==============================] - 2s 197ms/step - loss: 0.6144 - accuracy: 0.4645 - val_loss: 0.6062 - val_accuracy: 0.4353
# Epoch 5/10
# 11/11 [==============================] - 2s 190ms/step - loss: 0.6032 - accuracy: 0.4645 - val_loss: 0.6018 - val_accuracy: 0.4353
# Epoch 6/10
# 11/11 [==============================] - 2s 196ms/step - loss: 0.5900 - accuracy: 0.4704 - val_loss: 0.6071 - val_accuracy: 0.4471
# Epoch 7/10
# 11/11 [==============================] - 2s 188ms/step - loss: 0.5645 - accuracy: 0.5385 - val_loss: 0.6240 - val_accuracy: 0.4706
# Epoch 8/10
# 11/11 [==============================] - 2s 190ms/step - loss: 0.5314 - accuracy: 0.5976 - val_loss: 0.6411 - val_accuracy: 0.4588
# Epoch 9/10
# 11/11 [==============================] - 2s 189ms/step - loss: 0.4889 - accuracy: 0.6509 - val_loss: 0.6432 - val_accuracy: 0.4824
# Epoch 10/10
# 11/11 [==============================] - 2s 189ms/step - loss: 0.4265 - accuracy: 0.6893 - val_loss: 0.6699 - val_accuracy: 0.4824
#        loss  accuracy  val_loss  val_accuracy
# 0  0.686650  0.423077  0.674559      0.435294
# 1  0.651942  0.461538  0.635720      0.435294
# 2  0.620588  0.455621  0.614684      0.435294
# 3  0.614390  0.464497  0.606239      0.435294
# 4  0.603204  0.464497  0.601829      0.435294
# 5  0.590001  0.470414  0.607102      0.447059
# 6  0.564511  0.538462  0.624019      0.470588
# 7  0.531381  0.597633  0.641083      0.458824
# 8  0.488861  0.650888  0.643153      0.482353
# 9  0.426459  0.689349  0.669922      0.482353

# %%
#Repeat the process for each individual topic...
#For TV...

#Get dummy values for my sentiment scoring
y_TV = pd.get_dummies(df_TV['my_sentiment_for_vader']).values

# %%
tweet = df_TV.clean_text.values
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(tweet)
vocab_size = len(tokenizer.word_index) + 1
encoded_docs = tokenizer.texts_to_sequences(tweet)
padded_sequence = pad_sequences(encoded_docs, maxlen=200)


embedding_vector_length = 32
model = Sequential() 
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200) )
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax')) 
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])  
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 200, 32)           27328
#
#  spatial_dropout1d_2 (Spatia  (None, 200, 32)          0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 50)                16600
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 44,081
# Trainable params: 44,081
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(padded_sequence, y_TV, validation_split=0.2, epochs=10, verbose=1, batch_size=32)

hist = pd.DataFrame(history.history)

hist
# Out:
# Epoch 1/10
# 3/3 [==============================] - 4s 367ms/step - loss: 0.6920 - accuracy: 0.3820 - val_loss: 0.6930 - val_accuracy: 0.1304
# Epoch 2/10
# 3/3 [==============================] - 1s 201ms/step - loss: 0.6859 - accuracy: 0.5955 - val_loss: 0.6949 - val_accuracy: 0.0435
# Epoch 3/10
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6792 - accuracy: 0.5843 - val_loss: 0.6978 - val_accuracy: 0.0435
# Epoch 4/10
# 3/3 [==============================] - 1s 201ms/step - loss: 0.6677 - accuracy: 0.5843 - val_loss: 0.7033 - val_accuracy: 0.0435
# Epoch 5/10
# 3/3 [==============================] - 1s 201ms/step - loss: 0.6514 - accuracy: 0.5843 - val_loss: 0.7179 - val_accuracy: 0.0435
# Epoch 6/10
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6218 - accuracy: 0.5843 - val_loss: 0.7997 - val_accuracy: 0.0435
# Epoch 7/10
# 3/3 [==============================] - 1s 209ms/step - loss: 0.5677 - accuracy: 0.5843 - val_loss: 1.0760 - val_accuracy: 0.0435
# Epoch 8/10
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5685 - accuracy: 0.5843 - val_loss: 1.0819 - val_accuracy: 0.0435
# Epoch 9/10
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5869 - accuracy: 0.5843 - val_loss: 0.9981 - val_accuracy: 0.0435
# Epoch 10/10
# 3/3 [==============================] - 1s 201ms/step - loss: 0.5535 - accuracy: 0.5843 - val_loss: 0.9393 - val_accuracy: 0.0435
#        loss  accuracy  val_loss  val_accuracy
# 0  0.691989  0.382022  0.692983      0.130435
# 1  0.685871  0.595506  0.694908      0.043478
# 2  0.679189  0.584270  0.697774      0.043478
# 3  0.667729  0.584270  0.703261      0.043478
# 4  0.651363  0.584270  0.717946      0.043478
# 5  0.621832  0.584270  0.799698      0.043478
# 6  0.567737  0.584270  1.076039      0.043478
# 7  0.568515  0.584270  1.081932      0.043478
# 8  0.586852  0.584270  0.998098      0.043478
# 9  0.553528  0.584270  0.939293      0.043478

# %%
#For politics...

#Get dummy values for my sentiment scoring
y_politics = pd.get_dummies(df_politics['my_sentiment_for_vader']).values

# %%
tweet = df_politics.clean_text.values
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(tweet)
vocab_size = len(tokenizer.word_index) + 1
encoded_docs = tokenizer.texts_to_sequences(tweet)
padded_sequence = pad_sequences(encoded_docs, maxlen=200)


embedding_vector_length = 32
model = Sequential() 
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200) )
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax')) 
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])  
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 200, 32)           42880
#
#  spatial_dropout1d_3 (Spatia  (None, 200, 32)          0
#  lDropout1D)
#
#  lstm_3 (LSTM)               (None, 50)                16600
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 59,633
# Trainable params: 59,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(padded_sequence, y_politics, validation_split=0.2, epochs=10, verbose=1, batch_size=32)

hist = pd.DataFrame(history.history)

hist
# Out:
# Epoch 1/10
# 4/4 [==============================] - 4s 301ms/step - loss: 0.6912 - accuracy: 0.4272 - val_loss: 0.6864 - val_accuracy: 0.6923
# Epoch 2/10
# 4/4 [==============================] - 1s 190ms/step - loss: 0.6834 - accuracy: 0.6699 - val_loss: 0.6778 - val_accuracy: 0.7308
# Epoch 3/10
# 4/4 [==============================] - 1s 193ms/step - loss: 0.6745 - accuracy: 0.6408 - val_loss: 0.6653 - val_accuracy: 0.7308
# Epoch 4/10
# 4/4 [==============================] - 1s 190ms/step - loss: 0.6605 - accuracy: 0.6408 - val_loss: 0.6427 - val_accuracy: 0.7308
# Epoch 5/10
# 4/4 [==============================] - 1s 195ms/step - loss: 0.6290 - accuracy: 0.6408 - val_loss: 0.5847 - val_accuracy: 0.7308
# Epoch 6/10
# 4/4 [==============================] - 1s 198ms/step - loss: 0.5651 - accuracy: 0.6505 - val_loss: 0.5100 - val_accuracy: 0.7308
# Epoch 7/10
# 4/4 [==============================] - 1s 190ms/step - loss: 0.5107 - accuracy: 0.6408 - val_loss: 0.4925 - val_accuracy: 0.7308
# Epoch 8/10
# 4/4 [==============================] - 1s 190ms/step - loss: 0.5104 - accuracy: 0.6408 - val_loss: 0.4741 - val_accuracy: 0.7308
# Epoch 9/10
# 4/4 [==============================] - 1s 193ms/step - loss: 0.5211 - accuracy: 0.6408 - val_loss: 0.4715 - val_accuracy: 0.7308
# Epoch 10/10
# 4/4 [==============================] - 1s 190ms/step - loss: 0.4883 - accuracy: 0.6408 - val_loss: 0.4768 - val_accuracy: 0.7308
#        loss  accuracy  val_loss  val_accuracy
# 0  0.691181  0.427184  0.686387      0.692308
# 1  0.683416  0.669903  0.677789      0.730769
# 2  0.674489  0.640777  0.665253      0.730769
# 3  0.660503  0.640777  0.642736      0.730769
# 4  0.628989  0.640777  0.584740      0.730769
# 5  0.565139  0.650485  0.510037      0.730769
# 6  0.510698  0.640777  0.492458      0.730769
# 7  0.510351  0.640777  0.474105      0.730769
# 8  0.521056  0.640777  0.471523      0.730769
# 9  0.488331  0.640777  0.476831      0.730769

# %%
#For others...

#Get dummy values for my sentiment scoring
y_others = pd.get_dummies(df_others['my_sentiment_for_vader']).values

# %%
tweet = df_others.clean_text.values
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(tweet)
vocab_size = len(tokenizer.word_index) + 1
encoded_docs = tokenizer.texts_to_sequences(tweet)
padded_sequence = pad_sequences(encoded_docs, maxlen=200)


embedding_vector_length = 32
model = Sequential() 
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200) )
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax')) 
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])  
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 200, 32)           45088
#
#  spatial_dropout1d_4 (Spatia  (None, 200, 32)          0
#  lDropout1D)
#
#  lstm_4 (LSTM)               (None, 50)                16600
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense_4 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 61,841
# Trainable params: 61,841
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(padded_sequence, y_others, validation_split=0.2, epochs=10, verbose=1, batch_size=32)

hist = pd.DataFrame(history.history)

hist
# Out:
# Epoch 1/10
# 5/5 [==============================] - 5s 280ms/step - loss: 0.6920 - accuracy: 0.3379 - val_loss: 0.6839 - val_accuracy: 0.5405
# Epoch 2/10
# 5/5 [==============================] - 1s 201ms/step - loss: 0.6846 - accuracy: 0.3724 - val_loss: 0.6702 - val_accuracy: 0.6486
# Epoch 3/10
# 5/5 [==============================] - 1s 195ms/step - loss: 0.6726 - accuracy: 0.4276 - val_loss: 0.6397 - val_accuracy: 0.7027
# Epoch 4/10
# 5/5 [==============================] - 1s 197ms/step - loss: 0.6434 - accuracy: 0.4069 - val_loss: 0.5336 - val_accuracy: 0.7027
# Epoch 5/10
# 5/5 [==============================] - 1s 193ms/step - loss: 0.6248 - accuracy: 0.3724 - val_loss: 0.5256 - val_accuracy: 0.7027
# Epoch 6/10
# 5/5 [==============================] - 1s 197ms/step - loss: 0.6253 - accuracy: 0.4138 - val_loss: 0.5544 - val_accuracy: 0.2973
# Epoch 7/10
# 5/5 [==============================] - 1s 195ms/step - loss: 0.6207 - accuracy: 0.3724 - val_loss: 0.5750 - val_accuracy: 0.2973
# Epoch 8/10
# 5/5 [==============================] - 1s 193ms/step - loss: 0.6126 - accuracy: 0.4621 - val_loss: 0.5830 - val_accuracy: 0.2973
# Epoch 9/10
# 5/5 [==============================] - 1s 201ms/step - loss: 0.6154 - accuracy: 0.4621 - val_loss: 0.5757 - val_accuracy: 0.2973
# Epoch 10/10
# 5/5 [==============================] - 1s 201ms/step - loss: 0.6149 - accuracy: 0.3793 - val_loss: 0.5729 - val_accuracy: 0.2973
#        loss  accuracy  val_loss  val_accuracy
# 0  0.691969  0.337931  0.683885      0.540541
# 1  0.684580  0.372414  0.670164      0.648649
# 2  0.672585  0.427586  0.639668      0.702703
# 3  0.643423  0.406897  0.533631      0.702703
# 4  0.624833  0.372414  0.525643      0.702703
# 5  0.625288  0.413793  0.554357      0.297297
# 6  0.620676  0.372414  0.574987      0.297297
# 7  0.612644  0.462069  0.583025      0.297297
# 8  0.615378  0.462069  0.575662      0.297297
# 9  0.614933  0.379310  0.572942      0.297297
